# %% [markdown]
# <a href="https://colab.research.google.com/github/vsa282005/Relatorio-Experimento-01-Vinicius-Da-Silva-Andrade-242004321/blob/main/Aula_4_Vibracao_Livre_Amortecida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p>
# <img src="https://drive.google.com/uc?export=view&id=11V3n1rpH6yrleTIJcS5Y01QblGW7DiZ4" style="float: center"/>
# </p>

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.13/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from plotly) (26.3)
# Requirement already satisfied: cufflinks in /usr/local/lib/python3.13/dist-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.13/dist-packages (from cufflinks) (2.1.3)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.13/dist-packages (from cufflinks) (2.2.3)
# Requirement already satisfied: plotly>=4.1.1 in /usr/local/lib/python3.13/dist-packages (from cufflinks) (5.24.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /usr/local/lib/python3.13/dist-packages (from cufflinks) (75.2.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from cufflinks) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.13/dist-packages (from cufflinks) (7.7.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython>=5.3.0->cufflinks) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets>=7.0.0->cufflinks) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets>=7.0.0->cufflinks) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from plotly>=4.1.1->cufflinks) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from plotly>=4.1.1->cufflinks) (26.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.13/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (6.5.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (5.11.1)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (7.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.26.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.3.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (4.11.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.13/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.13/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (26.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2026.6.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.13/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.20.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (4.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (4.14.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.19)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (4.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.13/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.4.0)

# %% [markdown]
# # Vibração Livre Amortecida

# %% [markdown]
# A equação do movimento de um sistema massa mola de 1 Grau de Liberdade, com massa $m$, amortecimento $c$ e rigidez $k$ para descrito por $x$.
#
# $$
# m \ddot{x}(t) + c \dot{x} + k x(t) = 0
# $$
#
# <p>
# <img src="https://drive.google.com/uc?export=view&id=1t831GctcB7xWBNU8ZsThdHHBB2OfbShu" style="center" width="300"/>
# </p>
#
# onde,
# $ m $ é a massa $[kg]$
# $ c $ é o amortecimento $[N s/m]$
# $ k $ é a rigidez $[N/m]$
#
# ou ainda,
#
# $$
# \ddot{u}(t) + 2 \xi \omega_n \dot{u} + \omega_n^2 u(t) = 0
# $$
#
# onde,
# $\omega_n$ é a frequência natural $[rad/s]$,
# $T $ é o período natural de oscilação $[s]$, ou seja $(T = 2\pi / \omega_n)$, e
# $\xi $ é a razão de amortecimento $[adim]$, normalmente apresentada em porcentagem.
#
#
# OBS: $f_n = \omega_n / (2\pi) [Hz]$
#
# A solução analítica é dada pela expressão de deslocamento, para $0 \leq \xi \leq 1$,:
#
# $$ u(t) = e^{-\xi \omega_n t} \left[ U_o \cos (\omega_d t) + \left( \frac{V_o + \xi \omega_n U_o}{\omega_d} \right) \sin (\omega_d t) \right] $$
#
# onde,
# $\omega_d = \omega_n \sqrt{1-\xi^2}$ é a frequência amortecida $[rad/s]$
# $ U_o $ é o deslocamento inicial $[m]$, e
# $ V_o $ é a velocidade inicial $[m/s]$.
#
# Ou ainda,
#
# $$ u(t) = A e^{-\xi \omega_n t} \cos (\omega_d t - \phi) $$
#
# onde,
# $A \cos \phi = U_o$ e $A \sin \phi = \frac{V_o + \xi \omega_n U_o}{\omega_d}$,
#
# Logo,
# a amplitude $$A = \sqrt{U_o^2 + \left( \frac{V_o + \xi \omega_n U_o}{\omega_d} \right)^2} $$
# , e
# o ângulo de fase $$\tan \phi =\left( {V_o + \xi \omega_n U_o} \right) / \left( {\omega_n U_o} \right) $$

# %% [markdown]
# # Exercício
#
# Implementar uma rotina para calcular o deslocamento ${u} (t)$ e a velocidade $\dot{u}  (t)$ do sistema de 1 GDL amortecido,
# <p>
# <img src="https://drive.google.com/uc?export=view&id=1t831GctcB7xWBNU8ZsThdHHBB2OfbShu" style="float: center" width="300"/>
# </p>
#
# **Responda as Questões:**
#
# - Leia sinal de arquivos '.csv' com o deslocamento $u (t)$ de resultado experimental, apresentada acima;
#
# - Estime a razão de amortecimento $\xi_{estimado}$, por decaimento exponencial;
#
# - Estime a frequência de oscilação $\omega_d$, por transformada de fourier;
#
# - Estime a frequência natural $\omega_n$
#
# **DICA:**
#
# 1. Utilize os comando `find_peaks` (**from** `scipy.signal`) para determinar a envoltoria $A e^{-\xi \omega_n t}$
# 2. Utilize os comando `numpy.polyfit` para determinar os coeficientes da reta
# $
# \log x = - \xi \omega_n t + b = a t + b
# $
# pelO método de mínimos quadrado.

# %% [markdown]
# ## Importar as Bibliotecas

# %%
# 1GDL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# %% [markdown]
# ## Leitura de Dados

# %%
# !ls
# Out:
#  sample_data
# 'vibração muito amortecido (com 4 massas).txt'
# 'vibração muito amortecido (com 6 massas).txt'
# 'vibração pouco amortecido (com 4 massas).txt'
# 'vibração pouco amortecido (com 6 massas).txt'

# %%
# Path to the CSV file in GitHub
url = 'https://raw.githubusercontent.com/mumorais/ENM_UnB-Vibracoes_Exp/refs/heads/main/1gdl_ex_2.csv'

# Path to the CSV file in Google Colab Files
# Mas é preciso importar o arquivo csv para diretório
# Não se esqueça de inserir os arquivo
#
url = 'vibração pouco amortecido (com 4 massas).txt'

uvnum = pd.read_csv(url, sep = ',')
uvnum.head()
# Out:
#        t      x      vx  Unnamed: 3
# 0  0.000  5.580     NaN         NaN
# 1  0.033  5.575  -0.724         NaN
# 2  0.067  5.532  -2.901         NaN
# 3  0.100  5.382  -7.818         NaN
# 4  0.133  5.011 -15.300         NaN

# %%
import plotly.express as px
import pandas as pd
import plotly.io as pio

pio.renderers.default = 'colab'

df = pd.DataFrame({
    'Categoria': ['A', 'B', 'C'],
    'Valor': [10, 20, 30]
})

fig = px.line(uvnum, x='t', y='x', title='Histórico temporal do Deslocamento u(t) do sistema 1Gdl')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0892c9a3-e016-4114-b4b4-63b88f008889" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0892c9a3-e016-4114-b4b4-63b88f008889")) {                    Plotly.newPlot(                        "0892c9a3-e016-4114-b4b4-63b88f008889",                        [{"hovertemplate":"t=%{x}\u003cbr\u003ex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[0.0,0.033,0.067,0.1,0.133,0.167,0.2,0.233,0.267,0.3,0.333,0.367,0.4,0.433,0.467,0.5,0.533,0.567,0.6,0.633,0.667,0.7,0.733,0.767,0.8,0.833,0.866,0.9,0.933,0.966,1.0,1.033,1.066,1.1,1.133,1.166,1.2,1.233,1.266,1.3,1.333,1.366,1.4,1.433,1.466,1.5,1.533,1.566,1.6,1.633,1.666,1.7,1.733,1.766,1.8,1.833,1.866,1.9,1.933,1.966,2.0,2.033,2.066,2.1,2.133,2.166,2.2,2.233,2.266,2.3,2.333,2.366,2.4,2.433,2.466,2.499,2.533,2.566,2.599,2.633,2.666,2.699,2.733,2.766,2.799,2.833,2.866,2.899,2.933,2.966,2.999,3.033,3.066,3.099,3.133,3.166,3.199,3.233,3.266,3.299,3.333,3.366,3.399,3.433,3.466,3.499,3.533,3.566,3.599,3.633,3.666,3.699,3.733,3.766,3.799,3.833,3.866,3.899,3.933,3.966,3.999,4.033,4.066,4.099,4.133,4.166,4.199,4.232,4.266,4.299,4.332,4.366,4.399,4.432,4.466,4.499,4.532,4.566,4.599,4.632,4.666,4.699,4.732,4.766,4.799,4.832,4.866,4.899,4.932,4.966,4.999,5.032,5.066,5.099,5.132,5.166,5.199,5.232,5.266,5.299,5.332,5.366,5.399,5.432,5.466,5.499,5.532,5.566,5.599,5.632,5.666,5.699,5.732,5.766,5.799,5.832,5.865,5.899,5.932,5.965,5.999,6.032,6.065,6.099,6.132,6.165,6.199,6.232,6.265,6.299,6.332,6.365,6.399,6.432,6.465,6.499,6.532,6.565,6.599,6.632,6.665,6.699,6.732,6.765,6.799,6.832,6.865,6.899,6.932,6.965,6.999,7.032,7.065,7.099,7.132,7.165,7.199,7.232,7.265,7.299,7.332,7.365,7.399,7.432,7.465,7.498,7.532,7.565,7.598,7.632,7.665,7.698,7.732,7.765,7.798,7.832,7.865,7.898,7.932,7.965,7.998,8.032,8.065,8.098,8.132,8.165,8.198,8.232,8.265,8.298,8.332,8.365,8.398,8.432,8.465,8.498,8.532,8.565,8.598,8.632,8.665,8.698,8.732,8.765,8.798,8.832,8.865,8.898,8.932,8.965,8.998,9.032,9.065,9.098,9.131,9.165,9.198,9.231,9.265,9.298,9.331,9.365,9.398,9.431,9.465,9.498,9.531,9.565,9.598,9.631,9.665,9.698,9.731,9.765,9.798,9.831,9.865,9.898,9.931,9.965,9.998,10.031,10.065,10.098,10.131,10.165,10.198,10.231,10.265,10.298,10.331,10.365,10.398,10.431,10.465,10.498,10.531,10.565,10.598,10.631,10.665,10.698,10.731,10.765,10.798,10.831,10.864,10.898,10.931,10.964,10.998,11.031,11.064,11.098,11.131,11.164,11.198,11.231,11.264,11.298,11.331,11.364,11.398,11.431,11.464,11.498,11.531,11.564,11.598,11.631,11.664,11.698,11.731,11.764,11.798,11.831,11.864,11.898,11.931,11.964,11.998,12.031,12.064,12.098,12.131,12.164,12.198,12.231,12.264,12.298,12.331,12.364,12.398,12.431,12.464,12.497,12.531,12.564,12.597,12.631,12.664,12.697,12.731,12.764,12.797,12.831,12.864,12.897,12.931,12.964,12.997,13.031,13.064,13.097,13.131,13.164,13.197,13.231,13.264,13.297,13.331,13.364,13.397,13.431,13.464,13.497,13.531,13.564,13.597,13.631,13.664,13.697,13.731,13.764,13.797,13.831,13.864,13.897,13.931,13.964,13.997,14.031,14.064,14.097,14.13,14.164,14.197,14.23,14.264,14.297,14.33,14.364,14.397,14.43,14.464,14.497,14.53,14.564,14.597,14.63,14.664,14.697,14.73,14.764,14.797,14.83,14.864,14.897,14.93,14.964,14.997,15.03,15.064,15.097,15.13,15.164,15.197,15.23,15.264,15.297,15.33,15.364,15.397,15.43,15.464,15.497,15.53,15.564,15.597,15.63,15.664,15.697,15.73,15.764,15.797,15.83,15.863,15.897,15.93,15.963,15.997,16.03,16.063,16.097,16.13,16.163,16.197,16.23,16.263,16.297,16.33,16.363,16.397,16.43,16.463,16.497,16.53,16.563,16.597,16.63,16.663,16.697,16.73,16.763,16.797,16.83,16.863,16.897,16.93,16.963,16.997,17.03,17.063,17. ...

# %%
# Estime a Frequência de Oscilação
# Periodo:    Dt/N
# Frequência: N/Dt ,
#            onde  N é o número de oscilações e
#                 Dt é o intervalo de tempo.
TT = 4.366/10
display(TT)
ffreq = 1/TT
display(ffreq)
# Out:
# 0.4366
# 2.2904260192395784

# %% [markdown]
# ### DataFrame to Numpy.Array

# %%
Time = uvnum['t'].to_numpy()
U_t  = uvnum['x' ].to_numpy()
V_t  = uvnum['vx' ].to_numpy()

U_t = U_t - np.mean(U_t)

# %%
plt.figure(figsize=(10,4))
plt.plot(Time,(U_t))
plt.grid()
plt.xlim(0,20)
#plt.ylim(1e-3,1e-1)
plt.show()

# %% [markdown]
# ## Decaimento Exponencial
#
# A solução temporal de massa-mola com amortecimento subcrítico, é dado pela expressão:
#
# $$ x(t) = A e^{-\xi \omega_n t} \cos (\omega_d t - \phi). $$
#
# Como a função harmonico $\cos (\omega_d t - \phi)$ é limitada em $[-1; +1]$, temos uma envoltoria entorno de $u(t)$ dada pela expressão:
#
# $$ a(t) = A e^{-\xi \omega_n t}. $$

# %%
from scipy.signal import find_peaks
peaks, _ = find_peaks(U_t, height=0.005)

Time_peaks = Time[peaks]
U_t__peaks =  U_t[peaks]

# %%
plt.figure(figsize=(10,4))
plt.plot(Time,U_t)
plt.plot(Time[peaks],U_t[peaks],'r.',markersize=10)
plt.grid()
plt.show()

# %% [markdown]
# Aplica-se logaritmo $\ln(...)$ em ambos os lados da epxressão da envoltoria $a(t)$ a fim de obter a expressão linear:
# $$ \ln a(t) = \ln A e^{-\xi \omega_n t} = \ln A -\xi \omega_n t .$$
#
# Temos a expressão linear do tipo $$Y = c_0 - c_1 X ,$$
# onde,
# as coordenadas são dadas pela expressão $Y = \ln a(t)$ e $X = t$,
# e os coeficientes da equação linear são:
# 1. inclinação (coeficiente angular) $c_1 = \xi \omega_n$
# 2. constante  (coeficiente linear ) $c_0 = \ln A $

# %%
plt.figure(figsize=(10,2))
plt.semilogy(Time,np.abs(U_t))
plt.plot(Time[peaks],np.abs(U_t[peaks]),'r.',markersize=15)
plt.xlim(0,7)
plt.ylim(1e-3,1.0e-0)
plt.show()

# %% [markdown]
# ## Ajuste de Curva
#
# E, aplica-se o comando `polyfit` (`from numpy`), para determinar os coeficiente $c_0$ e $c_1$ da equação linear
#
# $$Y = c_0 - c_1 X .$$

# %%
polinomio = np.polyfit(Time_peaks, np.log(U_t__peaks), 1)
#logx = a t + b
coef_a = polinomio[0] #-qsi*wn
coef_b = polinomio[1] #relacionado as condições iniciais
print(polinomio)
print(np.round(coef_a,4))
print(np.round(coef_b,6))
# Out:
# [-0.01929752  0.82214088]
# -0.0193
# 0.822141

# %%
# Plotar a reta resultante (melhor ajuste LSE)
t0 = 0.5 #tempo inicial do intervalo
tf = 10.0 #tempo final do intervalo
dt = 0.01
Time_lse = np.arange(t0,tf,dt)

# %%
plt.figure(figsize=(6,2))
plt.plot(Time_peaks, np.log(U_t__peaks), 'rx', label = 'experimental')
plt.plot(Time_lse  , coef_a*Time_lse + coef_b, '--k',
         label = 'ajuste, a = %2.4f e exp(b) = %2.4f' %(coef_a, np.exp(coef_b)))
plt.xlabel(r'$t_i$')
plt.ylabel(r'log $x_i$')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Determinação da Frequência de Oscilação

# %%
# Análise de frequência FFT
u_frq = np.fft.fft(U_t)
n = len(U_t)
nhalf = int(np.floor(n/2))
delta = Time[1] - Time[0]
frq = np.fft.fftfreq(n, d=delta)

# %% [markdown]
# Novamente, utilizando os comando `find_peaks` (**from** `scipy.signal`), determina-se o pico de frequência do spectro de frequência $\hat{u}$, obtido por transformada de Fourier ($\hat{u} = \mathcal{F} (u)$).

# %%
u_frq_max = np.max(abs(u_frq))
peaks_index, properties = find_peaks(np.abs(u_frq),height = u_frq_max/2)
print('indice pico : ',peaks_index[0])
print('freq. pico',frq[peaks_index[0]])
wd_fft = frq[peaks_index[0]]*2*np.pi
# Out:
# indice pico :  84
# freq. pico 1.9298366531118616

# %%
plt.figure(figsize=(6,2))
plt.semilogy(frq[0:nhalf-1],np.abs(u_frq[0:nhalf-1]),'b.')
plt.semilogy(frq[peaks_index[0]],np.abs(u_frq[peaks_index[0]]),'ro')
plt.xlabel('Frequence (Hz)')
plt.ylabel('abs(U) (m/s)')
plt.xlim(0,4)
plt.ylim(1e-1,1e3)
plt.grid()
plt.show()

# %% [markdown]
# ## Estimativa da Frequência Natural
#
# Como o frequência amortecida $\omega_d = \omega_n \sqrt{1 - \xi^2}$, elevando ao quadrado em ambos os lados a expressão temos:
#
# $$ \omega^2_d = \omega^2_n - \left( \xi \omega_n \right)^2 $$
#
# Ou seja,
#
# $$ \omega_d^2 = \omega^2_n - c_1^2 $$
#
# Logo, a frequência natural $\omega_n$ pode ser estimada por:
#
# $$ \omega_n = \sqrt{\omega_d^2 + c_1^2}$$

# %%
# 1st Estimativa
# considerando wn ~ wd
wn = 2*np.pi*frq[peaks_index[0]] #aproximação wd = wn
qsi = - coef_a/wn
print(wn/2/np.pi,qsi*100) #frequencia natural, Hz & amortecimento
# Out:
# 1.9298366531118616 0.15914798961909435

# %%
#estimativa erro na aproximação wd por wn
wd = wn*np.sqrt(1 - qsi**2)
print(wn/2/np.pi, wd/2/np.pi, np.sqrt(1-qsi**2))
# Out:
# 1.9298366531118616 1.9298342091572065 0.9999987335950681

# %%
# 2st Estimativa
# considerando wn != wd
wn = np.sqrt(wd_fft**2 + coef_a**2)
qsi = - coef_a/wn
print(wn/2/np.pi,qsi*100) #frequencia natural, Hz & amortecimento
# Out:
# 1.9298390970634218 0.15914778807380586

# %% [markdown]
# ## Refinar a Estimação da Frequência

# %% [markdown]
# ### Background: DFT of a Sinusoid
#
# If your signal is a pure sinusoid:
#
# $$ y[n] =  A \cos (2\pi f_o n T + \phi)$$
#
# where:
#
# * $f_o$ is a not exactly on a DFT bin;
#
# * $T$ is the sampling interval
#
# * $N$ is the DFT size,
#
# then the DFT will **leak** — spreading power across several bins instead of a single one.
#
# This spectral leakage causes the true peak to lie between two DFT bins.

# %% [markdown]
# ### Quadratic Interpolation

# %% [markdown]
# Even though DFT values are sampled at discrete frequencies, the underlying spectrum of a single frequency sinusoid is smooth. The magnitude of the FFT near a peak follows a smooth curve, and if you zoom in near the peak, it resembles a parabola. So we model the magnitude near the peak using a quadratic function:
#
# $$ y(k) = a (k-k_o)^2 + b$$
#
# where, $k_o$ é a localização verdadeira (localizada entre os indices inteiros), $y(k)$ é a magnitude da FFT no k-éssimo 'bin' (intervalo de frequência discreto).
#
# We then take three points:
#
# *   $y_{-1} = |X[k-1]|$
# *   $y_{ 0}  = |X[k]|$
# *   $y_{+1} = |X[k+1]|$
#
# And fit a parabola through them to estimate the sub-bin peak location.

# %% [markdown]
# ### Derivation of the Formula
# Assume the three points lie on a parabola. The vertex of a parabola defined by 3 points, $(x_{-1},y_{-1})$, $(x_{0},y_{0})$, and $(x_{+1},y_{+1})$, can be found analytically.
#
# The general expression of a parabola is donne by:
#
# $$ y = a x^2 + b x + c$$
#
# Let the three points be:
#
# $$
# (-1,\alpha) = (k-1,y_{-1}), \quad
# ( 0,\beta ) = (k  ,y_{0} ), \quad
# (+1,\delta) = (k+1,y_{+1})
# $$
#
# We substitute the 3 known points into the general parabola:
#
# 1. At $x=-1$: $$ \alpha = a(-1)^2 + b(-1) + c  $$
#
# 2. At $x= 0$: $$ \beta  = a( 0)^2 + b( 0) + c \rightarrow \quad \therefore c = \beta $$
#
# 3. At $x=-1$: $$ \delta = a(+1)^2 + b(+1) + c  $$
#
# Now substitute $c = \beta$ into the others expression:
#
# * $ \alpha = a - b + \beta $
# * $ \delta = a + b + \beta $
#
# Operating $\alpha$ and $\delta$ expression, we have:
#
# $$ \alpha - \delta = -2b ⟹ \quad \therefore \quad b = - \frac{\alpha - \delta}{2}  $$
#
# $$ \alpha + \delta -2\beta = 2a ⟹ \quad \therefore \quad a = \frac{\alpha - 2\beta + \delta}{2}  $$
#
# As the vertex of a parabola is donne by $x_{vertex} = -b / (2a)$, then the location of the vertex relative to the center bin is:
#
# $$ p = \frac{1}{2} \cdot \frac{\alpha - \delta}{\alpha - 2\beta + \delta} $$
#
# Then the **refined peak location** is:
#
# $$ k_{interp} = k + p $$
#
# Convert that to frequency:
#
# $$ f_{interp} = f[k] + p \cdot \Delta f $$

# %% [markdown]
# ### Implementação da função `quadratic_interpolation`

# %%
def quadratic_interpolation(mag, k):
    # mag: magnitude spectrum
    # k: index of peak
    alpha = mag[k - 1]
    beta  = mag[k]
    delta = mag[k + 1]

    p = 0.5 * (alpha - delta) / (alpha - 2*beta + delta)
    return p

# %% [markdown]
# ### Aplication for Present Problem

# %%
p = quadratic_interpolation(np.abs(u_frq), peaks_index[0])
refined_freq = frq[peaks_index[0]] + p * (frq[1] - frq[0])

# %%
display(refined_freq)
# Out:
# np.float64(1.9294551139246594)

# %%
# 2st Estimativa
# considerando wn != wd
wn_refined = np.sqrt((2*np.pi*refined_freq)**2 + coef_a**2)
qsi = - coef_a/wn
#print(wn/2/np.pi,qsi*100) #frequencia natural, Hz & amortecimento
print('Valores Estimados')
print('wd = ',wn_refined*np.sqrt(1-qsi**2)/(2*pi),'Hz') # frequência amortecida
print('wn = ',wn_refined/(2*pi),'Hz')                   # frequencia natural
print('xi = ',qsi*100,'%')                              # razão de amorteicmento
# Out:
# Valores Estimados
# wd =  1.9294551148911183 Hz
# wn =  1.9294575583594973 Hz
# xi =  0.15914778807380586 %

# %%
# parametros
m = 30                           # kg
k = 15000                        # N/m
c= 2*0.02*m*(np.sqrt(k/m))
print('Valores Teóricos')
print('wd = ',np.sqrt(k/m)*np.sqrt(1-((c/m)/(2*wn))**2)/(2*pi),'Hz') # frequência amortecida
print('wn = ',np.sqrt(k/m)/(2*pi),'Hz')        # frequencia natural
print('xi = ',(c/m)/(2*wn))                    # razão de amorteicmento
# Out:
# Valores Teóricos
# wd =  3.556391403930275 Hz
# wn =  3.5588127170858854 Hz
# xi =  0.036881963086987136

# %%
# Faça a avaliação do erro entre as duas estimações
erro = (1-3.5700/3.5588)*100
display(erro)
erro = (1-3.6007/3.5588)*100
display(erro)
#1.6003165829418475 1.988997881843905
# Out:
# -0.31471282454758054
# -1.177363156120026
